# %%
import pandas as pd
import numpy as np
import scipy.io
import matlab.engine
eng = matlab.engine.start_matlab()
from scipy import misc
from IPython.display import clear_output

# %%
def generate_files_view_plane(writer_address,number_of_set):
    clear_output()
    #loading the name of patient files as per view
    A4C=pd.read_excel('/data/Gurpreet/Echo/Excel_Files/View_point_22062017.xlsx', sheetname='A4C', header=0)
    A2C=pd.read_excel('/data/Gurpreet/Echo/Excel_Files/View_point_22062017.xlsx', sheetname='A2C', header=0)
    PLA=pd.read_excel('/data/Gurpreet/Echo/Excel_Files/View_point_22062017.xlsx', sheetname='PLA', header=0)
            
    #Shuffles with index dropped
    Shuffled_A4C=A4C.sample(frac=1).reset_index(drop=True)
    A4C_Train_Set=Shuffled_A4C.ix[0:48,:]
    A4C_Test_Set=Shuffled_A4C.ix[49:60,:]
    A4C_Train_Set.to_excel(writer,sheet_name='Train_A4C',header=True)
    A4C_Test_Set.to_excel(writer,sheet_name='Test_A4C',header=True)
    writer.save()
    
    #Shuffles with index dropped
    Shuffled_A2C=A2C.sample(frac=1).reset_index(drop=True)
    A2C_Train_Set=Shuffled_A2C.ix[0:48,:]
    A2C_Test_Set=Shuffled_A2C.ix[49:60,:]
    A2C_Train_Set.to_excel(writer,sheet_name='Train_A2C',header=True)
    A2C_Test_Set.to_excel(writer,sheet_name='Test_A2C',header=True)
    writer.save()
    
    #Shuffles with index dropped
    Shuffled_PLA=PLA.sample(frac=1).reset_index(drop=True)
    PLA_Train_Set=Shuffled_PLA.ix[0:48,:]
    PLA_Test_Set=Shuffled_PLA.ix[49:60,:]
    PLA_Train_Set.to_excel(writer,sheet_name='Train_PLA',header=True)
    PLA_Test_Set.to_excel(writer,sheet_name='Test_PLA',header=True)
    writer.save()
    print "SAVING "+number_of_set
    
    for i in xrange(0,48):
        patnumber=Shuffled_A4C.iloc[i,0]
        Videonumber=Shuffled_A4C.iloc[i,1]
        Totalframes=Shuffled_A4C.iloc[i,2]
        Viewplane=Shuffled_A4C.iloc[i,3]
        imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(Videonumber)+").dcm"
        [MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info3(imgname,220,nargout=3)
        tempfile="/home/gus2011/tempimage_220.mat"
        IMG=scipy.io.loadmat(tempfile, mat_dtype=True)['IMG']
        SoI=IMG.shape
        Totalframes=SoI[3]
        print "TRAIN : "+imgname+"    "+Viewplane
        for j in xrange(0,Totalframes):
            IMG2=IMG[:,:,:,j]
            k=j+1
            savename="/data/Gurpreet/RUNS/VC_8/"+str(number_of_set)+"/TRAIN/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(k)+".jpg"
            IM=IMG2
            #IM=GE(IMG2,MANUFACTURER,WIDTH,HEIGHT,0)
            misc.imsave(savename,IM)
            
    for i in xrange(49,60):
        patnumber=Shuffled_A4C.iloc[i,0]
        Videonumber=Shuffled_A4C.iloc[i,1]
        Totalframes=Shuffled_A4C.iloc[i,2]
        Viewplane=Shuffled_A4C.iloc[i,3]
        imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(Videonumber)+").dcm"
        [MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info3(imgname,220,nargout=3)
        tempfile="/home/gus2011/tempimage_220.mat"
        IMG=scipy.io.loadmat(tempfile, mat_dtype=True)['IMG']
        SoI=IMG.shape
        Totalframes=SoI[3]
        print "TEST : "+imgname+"    "+Viewplane
        for j in xrange(0,Totalframes):
            IMG2=IMG[:,:,:,j]
            k=j+1
            savename="/data/Gurpreet/RUNS/VC_8/"+str(number_of_set)+"/TEST/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(k)+".jpg"
            IM=IMG2
            #IM=GE(IMG2,MANUFACTURER,WIDTH,HEIGHT,0)
            misc.imsave(savename,IM)
   
    for i in xrange(0,48):
        patnumber=Shuffled_A2C.iloc[i,0]
        Videonumber=Shuffled_A2C.iloc[i,1]
        Totalframes=Shuffled_A2C.iloc[i,2]
        Viewplane=Shuffled_A2C.iloc[i,3]
        imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(Videonumber)+").dcm"
        [MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info3(imgname,220,nargout=3)
        tempfile="/home/gus2011/tempimage_220.mat"
        IMG=scipy.io.loadmat(tempfile, mat_dtype=True)['IMG']
        SoI=IMG.shape
        Totalframes=SoI[3]
        print "TRAIN : "+imgname+"    "+Viewplane
        for j in xrange(0,Totalframes):
            IMG2=IMG[:,:,:,j]
            k=j+1
            savename="/data/Gurpreet/RUNS/VC_8/"+str(number_of_set)+"/TRAIN/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(k)+".jpg"
            IM=IMG2
            #IM=GE(IMG2,MANUFACTURER,WIDTH,HEIGHT,0)
            misc.imsave(savename,IM)
            
    for i in xrange(49,60):
        patnumber=Shuffled_A2C.iloc[i,0]
        Videonumber=Shuffled_A2C.iloc[i,1]
        Totalframes=Shuffled_A2C.iloc[i,2]
        Viewplane=Shuffled_A2C.iloc[i,3]
        imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(Videonumber)+").dcm"
        [MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info3(imgname,220,nargout=3)
        tempfile="/home/gus2011/tempimage_220.mat"
        IMG=scipy.io.loadmat(tempfile, mat_dtype=True)['IMG']
        SoI=IMG.shape
        Totalframes=SoI[3]
        print "TEST : "+imgname+"    "+Viewplane
        for j in xrange(0,Totalframes):
            IMG2=IMG[:,:,:,j]
            k=j+1
            savename="/data/Gurpreet/RUNS/VC_8/"+str(number_of_set)+"/TEST/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(k)+".jpg"
            IM=IMG2
            #IM=GE(IMG2,MANUFACTURER,WIDTH,HEIGHT,0)
            misc.imsave(savename,IM)

    for i in xrange(0,48):
        patnumber=Shuffled_PLA.iloc[i,0]
        Videonumber=Shuffled_PLA.iloc[i,1]
        Totalframes=Shuffled_PLA.iloc[i,2]
        Viewplane=Shuffled_PLA.iloc[i,3]
        imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(Videonumber)+").dcm"
        [MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info3(imgname,220,nargout=3)
        tempfile="/home/gus2011/tempimage_220.mat"
        IMG=scipy.io.loadmat(tempfile, mat_dtype=True)['IMG']
        SoI=IMG.shape
        Totalframes=SoI[3]
        print "TRAIN : "+imgname+"    "+Viewplane
        for j in xrange(0,Totalframes):
            IMG2=IMG[:,:,:,j]
            k=j+1
            savename="/data/Gurpreet/RUNS/VC_8/"+str(number_of_set)+"/TRAIN/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(k)+".jpg"
            IM=IMG2
            #IM=GE(IMG2,MANUFACTURER,WIDTH,HEIGHT,0)
            misc.imsave(savename,IM)
            
    for i in xrange(49,60):
        patnumber=Shuffled_PLA.iloc[i,0]
        Videonumber=Shuffled_PLA.iloc[i,1]
        Totalframes=Shuffled_PLA.iloc[i,2]
        Viewplane=Shuffled_PLA.iloc[i,3]
        imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(Videonumber)+").dcm"
        [MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info3(imgname,220,nargout=3)
        tempfile="/home/gus2011/tempimage_220.mat"
        IMG=scipy.io.loadmat(tempfile, mat_dtype=True)['IMG']
        SoI=IMG.shape
        Totalframes=SoI[3]
        print "TEST : "+imgname+"    "+Viewplane
        for j in xrange(0,Totalframes):
            IMG2=IMG[:,:,:,j]
            k=j+1
            savename="/data/Gurpreet/RUNS/VC_8/"+str(number_of_set)+"/TEST/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(k)+".jpg"
            IM=IMG2
            #IM=GE(IMG2,MANUFACTURER,WIDTH,HEIGHT,0)
            misc.imsave(savename,IM)

# %%
for i in xrange(9,10):
    #i=9
    x=i+1
    number_of_set="SET"+str(x)
    path_to_excel="/data/Gurpreet/RUNS/VC_8/"+str(number_of_set)+"/Data.xls"
    writer=pd.ExcelWriter(path_to_excel)
    generate_files_view_plane(writer,number_of_set)
# Out:
# SAVING SET10
# TRAIN : /data/Gurpreet/Echo/95/95(40).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/57/57(27).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/40/40(38).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/22/22(48).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/62/62(43).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/54/54(36).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/31/31(47).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/57/57(43).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/97/97(59).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/41/41(46).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/67/67(35).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/54/54(20).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/98/98(50).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/41/41(41).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/98/98(39).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/61/61(29).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/97/97(32).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/94/94(38).dcm    A4C
# TRAIN : /data/Gurpreet/Echo/57/57(41).dcm    A4C
# ...
