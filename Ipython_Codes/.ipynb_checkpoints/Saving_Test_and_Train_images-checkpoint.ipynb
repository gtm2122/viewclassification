# %%
import sys
sys.path.append('/data/Gurpreet/CODE/VC2/OCR')
import numpy as np
from conv import get_echo as GE

import matlab.engine
import numpy as np
eng = matlab.engine.start_matlab()
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import skimage.io as io
from scipy import misc

# %%
Testfiles=pd.read_excel('/data/Gurpreet/Echo/Excel_Files/View_point2.xlsx', sheetname='Test', header=0)
import scipy.io
for i in xrange(1,((Testfiles.size/4))):
    patnumber=Testfiles.iloc[i,0]
    Videonumber=Testfiles.iloc[i,1]
    Viewplane=Testfiles.iloc[i,3]
    imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(Videonumber)+").dcm"
    [MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info3(imgname,220,nargout=3)
    tempfile="/home/gus2011/tempimage_220.mat"
    IMG=scipy.io.loadmat(tempfile, mat_dtype=True)['IMG']
    SoI=IMG.shape
    Totalframes=SoI[3]
    if (Viewplane.lower()=='a4c') or (Viewplane.lower()=='a2c') or (Viewplane.lower()=='pla'):
        print imgname+"    "+Viewplane
        for j in xrange(0,Totalframes):
            IMG2=IMG[:,:,:,j]
            k=j+1
            savename="/data/Gurpreet/RUNS/VC_5/TEST/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(k)+".jpg"
            IM=IMG2
            #IM=GE(IMG2,MANUFACTURER,WIDTH,HEIGHT,0)
            misc.imsave(savename,IM)
# Out:
# /data/Gurpreet/Echo/2/2(2).dcm    PLA
# /data/Gurpreet/Echo/2/2(3).dcm    PLA
# /data/Gurpreet/Echo/2/2(13).dcm    PLA
# /data/Gurpreet/Echo/2/2(15).dcm    PLA
# /data/Gurpreet/Echo/2/2(43).dcm    PLA
# /data/Gurpreet/Echo/2/2(47).dcm    A4C
# /data/Gurpreet/Echo/2/2(48).dcm    A4C
# /data/Gurpreet/Echo/2/2(69).dcm    A2C
# /data/Gurpreet/Echo/2/2(73).dcm    A4C
# /data/Gurpreet/Echo/2/2(78).dcm    A2C
# /data/Gurpreet/Echo/2/2(79).dcm    A4C
# /data/Gurpreet/Echo/3/3(1).dcm    PLA
# /data/Gurpreet/Echo/3/3(3).dcm    PLA
# /data/Gurpreet/Echo/3/3(7).dcm    A4C
# /data/Gurpreet/Echo/3/3(10).dcm    PLA
# /data/Gurpreet/Echo/3/3(13).dcm    PLA
# /data/Gurpreet/Echo/3/3(15).dcm    A2C
# /data/Gurpreet/Echo/3/3(40).dcm    A4C
# /data/Gurpreet/Echo/3/3(42).dcm    A4C
# /data/Gurpreet/Echo/3/3(46).dcm    A4C
# /data/Gurpreet/Echo/3/3(50).dcm    A2C
# /data/Gurpreet/Echo/3/3(63).dcm    A2C
# /data/Gurpreet/Echo/3/3(65).dcm    A2C
# /data/Gurpreet/Echo/3/3(67).dcm    A2C
# /data/Gurpreet/Echo/3/3(69).dcm    A4C
# /data/Gurpreet/Echo/4/4(2).dcm    PLA
# /data/Gurpreet/Echo/4/4(6).dcm    PLA
# /data/Gurpreet/Echo/4/4(9).dcm    A2C
# /data/Gurpreet/Echo/4/4(12).dcm    A4C
# /data/Gurpreet/Echo/4/4(45).dcm    A4C
# /data/Gurpreet/Echo/4/4(52).dcm    A4C
# /data/Gurpreet/Echo/4/4(53).dcm    A4C
# /data/Gurpreet/Echo/4/4(57).dcm    A4C
# /data/Gurpreet/Echo/4/4(60).dcm    A2C
# /data/Gurpreet/Echo/4/4(61).dcm    A2C
# /data/Gurpreet/Echo/4/4(62).dcm    A2C
# /data/Gurpreet/Echo/4/4(63).dcm    A4C
# /data/Gurpreet/Echo/4/4(65).dcm    A4C
# /data/Gurpreet/Echo/4/4(66).dcm    A4C
# /data/Gurpreet/Echo/4/4(67).dcm    A4C
# /data/Gurpreet/Echo/5/5(2).dcm    PLA
# /data/Gurpreet/Echo/5/5(13).dcm    A4C
# /data/Gurpreet/Echo/5/5(16).dcm    PLA
# /data/Gurpreet/Echo/5/5(43).dcm    A4C
# /data/Gurpreet/Echo/5/5(55).dcm    A2C
# /data/Gurpreet/Echo/5/5(80).dcm    A4C
# /data/Gurpreet/Echo/5/5(82).dcm    A4C
# /data/Gurpreet/Echo/5/5(83).dcm    A2C
# /data/Gurpreet/Echo/5/5(88).dcm    A4C
# /data/Gurpreet/Echo/5/5(94).dcm    A4C
# /data/Gurpreet/Echo/5/5(106).dcm    A4C
# /data/Gurpreet/Echo/5/5(111).dcm    A4C
# /data/Gurpreet/Echo/5/5(125).dcm    PLA
# /data/Gurpreet/Echo/102/102(1).dcm    PLA
# /data/Gurpreet/Echo/102/102(2).dcm    PLA
# /data/Gurpreet/Echo/102/102(9).dcm    A4C
# /data/Gurpreet/Echo/102/102(26).dcm    A4C
# /data/Gurpreet/Echo/102/102(35).dcm    A2C
# /data/Gurpreet/Echo/102/102(38).dcm    A4C
# /data/Gurpreet/Echo/102/102(40).dcm    A2C
# /data/Gurpreet/Echo/102/102(41).dcm    A4C
# /data/Gurpreet/Echo/102/102(46).dcm    A4C

# %%
Trainfiles=pd.read_excel('/data/Gurpreet/Echo/Excel_Files/View_point2.xlsx', sheetname='Train', header=0)
import scipy.io
for i in xrange(0,((Trainfiles.size/4))):
    patnumber=Trainfiles.iloc[i,0]
    Videonumber=Trainfiles.iloc[i,1]
    Viewplane=Trainfiles.iloc[i,3]
    imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(Videonumber)+").dcm"
    [MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info3(imgname,220,nargout=3)
    tempfile="/home/gus2011/tempimage_220.mat"
    IMG=scipy.io.loadmat(tempfile, mat_dtype=True)['IMG']
    SoI=IMG.shape
    Totalframes=SoI[3]
    if (Viewplane.lower()=='a4c') or (Viewplane.lower()=='a2c') or (Viewplane.lower()=='pla'):
        print imgname+"    "+Viewplane
        for j in xrange(0,Totalframes):
            IMG2=IMG[:,:,:,j]
            k=j+1
            savename="/data/Gurpreet/RUNS/VC_6/TRAIN/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(k)+".jpg"
            IM=GE(IMG2,MANUFACTURER,WIDTH,HEIGHT,0)
            misc.imsave(savename,IM)
# Out:
# /data/Gurpreet/Echo/1/1(1).dcm    PLA
# /data/Gurpreet/Echo/1/1(8).dcm    PLA
# /data/Gurpreet/Echo/1/1(24).dcm    A4C
# /data/Gurpreet/Echo/1/1(38).dcm    A4C
# /data/Gurpreet/Echo/1/1(41).dcm    A2C
# /data/Gurpreet/Echo/1/1(42).dcm    A2C
# /data/Gurpreet/Echo/17/17(1).dcm    PLA
# /data/Gurpreet/Echo/17/17(2).dcm    PLA
# /data/Gurpreet/Echo/17/17(21).dcm    A4C
# /data/Gurpreet/Echo/17/17(22).dcm    A4C
# /data/Gurpreet/Echo/17/17(31).dcm    A4C
# /data/Gurpreet/Echo/17/17(33).dcm    A2C
# /data/Gurpreet/Echo/17/17(34).dcm    A2C
# /data/Gurpreet/Echo/22/22(1).dcm    PLA
# /data/Gurpreet/Echo/22/22(2).dcm    PLA
# /data/Gurpreet/Echo/22/22(3).dcm    PLA
# /data/Gurpreet/Echo/22/22(10).dcm    PLA
# /data/Gurpreet/Echo/22/22(31).dcm    A4C
# /data/Gurpreet/Echo/22/22(39).dcm    A2C
# /data/Gurpreet/Echo/22/22(42).dcm    A4C
# /data/Gurpreet/Echo/22/22(44).dcm    A2C
# /data/Gurpreet/Echo/22/22(48).dcm    A4C
# /data/Gurpreet/Echo/22/22(50).dcm    A2C
# /data/Gurpreet/Echo/31/31(1).dcm    PLA
# /data/Gurpreet/Echo/31/31(2).dcm    PLA
# /data/Gurpreet/Echo/31/31(47).dcm    A4C
# /data/Gurpreet/Echo/31/31(56).dcm    A2C
# /data/Gurpreet/Echo/31/31(62).dcm    A2C
# /data/Gurpreet/Echo/31/31(67).dcm    PLA
# /data/Gurpreet/Echo/32/32(1).dcm    PLA
# /data/Gurpreet/Echo/32/32(24).dcm    A4C
# /data/Gurpreet/Echo/32/32(27).dcm    A4C
# /data/Gurpreet/Echo/32/32(34).dcm    A2C
# /data/Gurpreet/Echo/32/32(38).dcm    A4C
# /data/Gurpreet/Echo/32/32(40).dcm    A2C
# /data/Gurpreet/Echo/32/32(41).dcm    A4C
# /data/Gurpreet/Echo/32/32(44).dcm    A4C
# /data/Gurpreet/Echo/35/35(1).dcm    PLA
# /data/Gurpreet/Echo/35/35(2).dcm    PLA
# /data/Gurpreet/Echo/35/35(6).dcm    PLA
# /data/Gurpreet/Echo/35/35(26).dcm    A4C
# /data/Gurpreet/Echo/35/35(40).dcm    A4C
# /data/Gurpreet/Echo/35/35(42).dcm    A2C
# /data/Gurpreet/Echo/35/35(47).dcm    A4C
# /data/Gurpreet/Echo/35/35(49).dcm    A2C
# /data/Gurpreet/Echo/38/38(1).dcm    PLA
# /data/Gurpreet/Echo/38/38(2).dcm    PLA
# /data/Gurpreet/Echo/38/38(3).dcm    PLA
# /data/Gurpreet/Echo/38/38(35).dcm    A2C
# /data/Gurpreet/Echo/38/38(38).dcm    A4C
# /data/Gurpreet/Echo/38/38(42).dcm    A2C
# /data/Gurpreet/Echo/38/38(43).dcm    A4C
# /data/Gurpreet/Echo/40/40(1).dcm    PLA
# /data/Gurpreet/Echo/40/40(2).dcm    PLA
# /data/Gurpreet/Echo/40/40(6).dcm    PLA
# /data/Gurpreet/Echo/40/40(8).dcm    PLA
# /data/Gurpreet/Echo/40/40(9).dcm    PLA
# /data/Gurpreet/Echo/40/40(10).dcm    PLA
# /data/Gurpreet/Echo/40/40(27).dcm    A4C
# /data/Gurpreet/Echo/40/40(36).dcm    A4C
# /data/Gurpreet/Echo/40/40(37).dcm    A2C
# /data/Gurpreet/Echo/40/40(38).dcm    A4C
# /data/Gurpreet/Echo/40/40(41).dcm    A2C
# /data/Gurpreet/Echo/40/40(42).dcm    A4C
# /data/Gurpreet/Echo/41/41(1).dcm    PLA
# /data/Gurpreet/Echo/41/41(2).dcm    PLA
# /data/Gurpreet/Echo/41/41(6).dcm    PLA
# /data/Gurpreet/Echo/41/41(8).dcm    PLA
# /data/Gurpreet/Echo/41/41(11).dcm    PLA
# /data/Gurpreet/Echo/41/41(30).dcm    A4C
# /data/Gurpreet/Echo/41/41(39).dcm    A4C
# /data/Gurpreet/Echo/41/41(40).dcm    A2C
# /data/Gurpreet/Echo/41/41(41).dcm    A4C
# /data/Gurpreet/Echo/41/41(43).dcm    A2C
# /data/Gurpreet/Echo/41/41(44).dcm    A2C
# /data/Gurpreet/Echo/41/41(46).dcm    A4C
# /data/Gurpreet/Echo/41/41(47).dcm    A2C
# /data/Gurpreet/Echo/46/46(1).dcm    PLA
# /data/Gurpreet/Echo/46/46(2).dcm    PLA
# /data/Gurpreet/Echo/46/46(6).dcm    PLA
# /data/Gurpreet/Echo/46/46(24).dcm    A4C
# /data/Gurpreet/Echo/46/46(31).dcm    A4C
# /data/Gurpreet/Echo/46/46(33).dcm    A2C
# /data/Gurpreet/Echo/46/46(34).dcm    A2C
# /data/Gurpreet/Echo/46/46(37).dcm    A4C
# /data/Gurpreet/Echo/54/54(1).dcm    PLA
# /data/Gurpreet/Echo/54/54(5).dcm    PLA
# /data/Gurpreet/Echo/54/54(20).dcm    A4C
# /data/Gurpreet/Echo/54/54(29).dcm    A4C
# /data/Gurpreet/Echo/54/54(31).dcm    A2C
# /data/Gurpreet/Echo/54/54(32).dcm    A2C
# /data/Gurpreet/Echo/54/54(36).dcm    A4C
# /data/Gurpreet/Echo/57/57(1).dcm    PLA
# /data/Gurpreet/Echo/57/57(2).dcm    PLA
# /data/Gurpreet/Echo/57/57(6).dcm    PLA
# /data/Gurpreet/Echo/57/57(27).dcm    A4C
# /data/Gurpreet/Echo/57/57(37).dcm    A2C
# /data/Gurpreet/Echo/57/57(38).dcm    A2C
# /data/Gurpreet/Echo/57/57(41).dcm    A4C
# /data/Gurpreet/Echo/57/57(42).dcm    A4C
# /data/Gurpreet/Echo/57/57(43).dcm    A4C
# /data/Gurpreet/Echo/57/57(46).dcm    A2C
# /data/Gurpreet/Echo/57/57(47).dcm    A2C
# /data/Gurpreet/Echo/57/57(48).dcm    A4C
# /data/Gurpreet/Echo/57/57(49).dcm    A2C
# /data/Gurpreet/Echo/57/57(52).dcm    A4C
# /data/Gurpreet/Echo/61/61(1).dcm    PLA
# /data/Gurpreet/Echo/61/61(2).dcm    PLA
# /data/Gurpreet/Echo/61/61(6).dcm    PLA
# /data/Gurpreet/Echo/61/61(8).dcm    PLA
# /data/Gurpreet/Echo/61/61(10).dcm    PLA
# /data/Gurpreet/Echo/61/61(29).dcm    A4C
# /data/Gurpreet/Echo/61/61(42).dcm    A2C
# /data/Gurpreet/Echo/61/61(45).dcm    A4C
# /data/Gurpreet/Echo/61/61(49).dcm    A4C
# /data/Gurpreet/Echo/61/61(51).dcm    A2C
# /data/Gurpreet/Echo/61/61(52).dcm    A4C
# /data/Gurpreet/Echo/62/62(1).dcm    PLA
# /data/Gurpreet/Echo/62/62(2).dcm    PLA
# /data/Gurpreet/Echo/62/62(6).dcm    PLA
# /data/Gurpreet/Echo/62/62(27).dcm    A4C
# /data/Gurpreet/Echo/62/62(28).dcm    A4C
# /data/Gurpreet/Echo/62/62(39).dcm    A2C
# /data/Gurpreet/Echo/62/62(42).dcm    A4C
# /data/Gurpreet/Echo/62/62(43).dcm    A4C
# /data/Gurpreet/Echo/62/62(46).dcm    A2C
# /data/Gurpreet/Echo/62/62(47).dcm    A2C
# /data/Gurpreet/Echo/62/62(48).dcm    A4C
# /data/Gurpreet/Echo/67/67(1).dcm    PLA
# /data/Gurpreet/Echo/67/67(2).dcm    PLA
# /data/Gurpreet/Echo/67/67(3).dcm    PLA
# /data/Gurpreet/Echo/67/67(7).dcm    PLA
# /data/Gurpreet/Echo/67/67(11).dcm    PLA
# /data/Gurpreet/Echo/67/67(35).dcm    A4C
# /data/Gurpreet/Echo/67/67(36).dcm    A4C
# /data/Gurpreet/Echo/67/67(44).dcm    A4C
# /data/Gurpreet/Echo/67/67(45).dcm    A4C
# /data/Gurpreet/Echo/67/67(49).dcm    A4C
# /data/Gurpreet/Echo/67/67(50).dcm    A2C
# /data/Gurpreet/Echo/67/67(52).dcm    A4C
# /data/Gurpreet/Echo/76/76(1).dcm    PLA
# /data/Gurpreet/Echo/76/76(2).dcm    PLA
# /data/Gurpreet/Echo/76/76(3).dcm    PLA
# /data/Gurpreet/Echo/76/76(6).dcm    PLA
# /data/Gurpreet/Echo/76/76(9).dcm    PLA
# /data/Gurpreet/Echo/76/76(38).dcm    A4C
# /data/Gurpreet/Echo/76/76(39).dcm    A4C
# /data/Gurpreet/Echo/76/76(49).dcm    A2C
# /data/Gurpreet/Echo/76/76(52).dcm    A4C
# /data/Gurpreet/Echo/76/76(54).dcm    A2C
# /data/Gurpreet/Echo/76/76(55).dcm    A4C
# /data/Gurpreet/Echo/76/76(56).dcm    A4C
# /data/Gurpreet/Echo/78/78(1).dcm    PLA
# /data/Gurpreet/Echo/78/78(2).dcm    PLA
# /data/Gurpreet/Echo/78/78(9).dcm    PLA
# /data/Gurpreet/Echo/78/78(13).dcm    PLA
# /data/Gurpreet/Echo/78/78(34).dcm    A4C
# /data/Gurpreet/Echo/78/78(42).dcm    A2C
# /data/Gurpreet/Echo/78/78(51).dcm    A4C
# /data/Gurpreet/Echo/78/78(52).dcm    A4C
# /data/Gurpreet/Echo/78/78(55).dcm    A2C
# /data/Gurpreet/Echo/78/78(56).dcm    A2C
# /data/Gurpreet/Echo/80/80(1).dcm    PLA
# /data/Gurpreet/Echo/80/80(2).dcm    PLA
# /data/Gurpreet/Echo/80/80(9).dcm    PLA
# /data/Gurpreet/Echo/80/80(27).dcm    A4C
# /data/Gurpreet/Echo/80/80(35).dcm    A2C
# /data/Gurpreet/Echo/80/80(40).dcm    A4C
# /data/Gurpreet/Echo/82/82(1).dcm    PLA
# /data/Gurpreet/Echo/82/82(18).dcm    A4C
# /data/Gurpreet/Echo/82/82(26).dcm    A2C
# /data/Gurpreet/Echo/82/82(30).dcm    A4C
# /data/Gurpreet/Echo/82/82(32).dcm    A2C
# /data/Gurpreet/Echo/85/85(1).dcm    PLA
# /data/Gurpreet/Echo/85/85(17).dcm    A4C
# /data/Gurpreet/Echo/85/85(26).dcm    A4C
# /data/Gurpreet/Echo/85/85(28).dcm    A2C
# /data/Gurpreet/Echo/85/85(32).dcm    A4C
# /data/Gurpreet/Echo/88/88(1).dcm    PLA
# /data/Gurpreet/Echo/92/92(1).dcm    PLA
# /data/Gurpreet/Echo/92/92(7).dcm    PLA
# /data/Gurpreet/Echo/92/92(24).dcm    A4C
# /data/Gurpreet/Echo/92/92(37).dcm    A2C
# /data/Gurpreet/Echo/94/94(1).dcm    PLA
# /data/Gurpreet/Echo/94/94(2).dcm    PLA
# /data/Gurpreet/Echo/94/94(6).dcm    PLA
# /data/Gurpreet/Echo/94/94(8).dcm    PLA
# /data/Gurpreet/Echo/94/94(10).dcm    PLA
# /data/Gurpreet/Echo/94/94(27).dcm    A4C
# /data/Gurpreet/Echo/94/94(36).dcm    A4C
# /data/Gurpreet/Echo/94/94(37).dcm    A2C
# /data/Gurpreet/Echo/94/94(38).dcm    A4C
# /data/Gurpreet/Echo/94/94(41).dcm    A2C
# /data/Gurpreet/Echo/94/94(42).dcm    A4C
# /data/Gurpreet/Echo/95/95(1).dcm    PLA
# /data/Gurpreet/Echo/95/95(2).dcm    PLA
# /data/Gurpreet/Echo/95/95(6).dcm    PLA
# /data/Gurpreet/Echo/95/95(8).dcm    PLA
# /data/Gurpreet/Echo/95/95(9).dcm    PLA
# /data/Gurpreet/Echo/95/95(29).dcm    A4C
# /data/Gurpreet/Echo/95/95(38).dcm    A4C
# /data/Gurpreet/Echo/95/95(39).dcm    A2C
# /data/Gurpreet/Echo/95/95(40).dcm    A4C
# /data/Gurpreet/Echo/95/95(42).dcm    A2C
# /data/Gurpreet/Echo/97/97(1).dcm    PLA
# /data/Gurpreet/Echo/97/97(2).dcm    PLA
# /data/Gurpreet/Echo/97/97(3).dcm    PLA
# /data/Gurpreet/Echo/97/97(7).dcm    PLA
# /data/Gurpreet/Echo/97/97(9).dcm    PLA
# /data/Gurpreet/Echo/97/97(32).dcm    A4C
# /data/Gurpreet/Echo/97/97(33).dcm    A4C
# /data/Gurpreet/Echo/97/97(37).dcm    A4C
# /data/Gurpreet/Echo/97/97(48).dcm    A2C
# /data/Gurpreet/Echo/97/97(51).dcm    A4C
# /data/Gurpreet/Echo/97/97(53).dcm    A2C
# /data/Gurpreet/Echo/97/97(54).dcm    A2C
# /data/Gurpreet/Echo/97/97(55).dcm    A4C
# /data/Gurpreet/Echo/97/97(59).dcm    A4C
# /data/Gurpreet/Echo/98/98(1).dcm    PLA
# /data/Gurpreet/Echo/98/98(2).dcm    PLA
# /data/Gurpreet/Echo/98/98(8).dcm    PLA
# /data/Gurpreet/Echo/98/98(9).dcm    PLA
# /data/Gurpreet/Echo/98/98(30).dcm    A4C
# /data/Gurpreet/Echo/98/98(39).dcm    A4C
# /data/Gurpreet/Echo/98/98(40).dcm    A2C
# /data/Gurpreet/Echo/98/98(41).dcm    A4C
# /data/Gurpreet/Echo/98/98(42).dcm    A4C
# /data/Gurpreet/Echo/98/98(45).dcm    A2C
# /data/Gurpreet/Echo/98/98(46).dcm    A4C
# /data/Gurpreet/Echo/98/98(48).dcm    A2C
# /data/Gurpreet/Echo/98/98(49).dcm    A4C
# /data/Gurpreet/Echo/98/98(50).dcm    A4C
# /data/Gurpreet/Echo/98/98(53).dcm    A4C
# /data/Gurpreet/Echo/100/100(1).dcm    PLA
# /data/Gurpreet/Echo/100/100(2).dcm    PLA
# /data/Gurpreet/Echo/100/100(21).dcm    A4C
# /data/Gurpreet/Echo/100/100(22).dcm    A4C
# /data/Gurpreet/Echo/100/100(31).dcm    A4C
# /data/Gurpreet/Echo/100/100(34).dcm    A2C
# /data/Gurpreet/Echo/100/100(35).dcm    A2C
# /data/Gurpreet/Echo/100/100(36).dcm    A2C
# /data/Gurpreet/Echo/100/100(39).dcm    A4C
# /data/Gurpreet/Echo/102/102(1).dcm    PLA
# /data/Gurpreet/Echo/102/102(2).dcm    PLA
# /data/Gurpreet/Echo/102/102(9).dcm    PLA
# /data/Gurpreet/Echo/102/102(26).dcm    A4C
# /data/Gurpreet/Echo/102/102(35).dcm    A2C
# /data/Gurpreet/Echo/102/102(38).dcm    A4C
# /data/Gurpreet/Echo/102/102(40).dcm    A2C
# /data/Gurpreet/Echo/102/102(41).dcm    A4C
# /data/Gurpreet/Echo/102/102(46).dcm    A4C
