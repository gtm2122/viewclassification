# %%
import matlab.engine
import numpy as np
eng = matlab.engine.start_matlab()
import pandas as pd

# %%
def get_echo(img,company,R,C,save_file):
    import matplotlib.pyplot as plt
    import numpy as np
    import skimage.io as io
    import dicom
    from scipy import misc
    #img = plt.imread(img_add)
    
    
    dic_m = {}
    
    dic_m["'GEMS Ultrasound' 636 422"] = [[0,316],[311,0],[411,186],[421,306],[421,586],[304,629],[0,316]]
    dic_m["'GEMS Ultrasound' 636 434"] = [[10,320],[320,10],[402,162],[400,600],[124,578],[10,320]]
    dic_m["'GE Vingmed Ultrasound' 636 434"] = [[7,319],[322,13],[401,241],[401,582],[7,577]]
    dic_m["'Philips Medical Systems' 800 600"]=[[98,426],[560,6],[568,636],[432,758],[426,98]]
    
    dic_m["'GE Healthcare Ultrasound' 1016 708"] = [[66,510],[505,84],[650,313],[663,524],[574,985],[60,510]]
    dic_m["'SIEMENS' 1024 768"] = [[30,474],[469,0],[673,0],[673,1024],[469,1023],[30,551]]
    
    if(company.lower()=='gems ultrasound' and R == 636 and C == 422):
        coords = np.array([np.arange(6,316),np.arange(316,6,-1)]).T
        for i in coords:
            #print(i)
            img[:i[0],:i[1]]=0

        coords = np.array([np.arange(350,420),np.arange(316,6,-1)]).T
        
        img[387:,:170]=0
        img[390:,603:]=0
        img[8:173,602:]=0
        
    elif (company.lower()=='siemens' and R == 1024 and C == 768):
        coords = np.array([np.arange(469,30,-1),np.arange(30,469)]).T
        for i in coords:
            img[:i[0],:i[1]]=0
        img[674:,:997]=0
        coords1 = np.array([np.arange(36,469),np.arange(561,993)]).T
        img[:258,755:] = 0
    
    elif company.lower()=='ge healthcare ultrasound' and R == 1016 and C == 708 :
        img[:148,:259] = 0
        ekg = img[650:,:]
        img[650:,:] = 0
        img[:,915:] = 0
        
    elif company.lower()=='gems ultrasound' and R == 636 and C == 434:
        img[:8,:] = 0
        img[0:42,:95]=0
        img[:63,:131] = 0
        img[:10,:] = 0
        img[:207,592:] = 0
        ekg = img[395:,:]
        img[393:,:] = 0
        
    elif(company.lower()=='ge vingmed ultrasound' and R == 636  and C == 434):
        img[:8,:] = 0
        img[0:42,:95]=0
        img[:63,:131] = 0
        img[:10,:] = 0
        img[:207,592:] = 0
        ekg = img[395:,:]
        img[393:,:] = 0
        
    elif(company.lower()=='philips medical systems' and R==800 and C ==600):
        img[:130,0:900]=0
        #print('here')
        img[:,:94]=0
        img[61:191,:220] = 0        
        img[:93,:431] = 0
        img[:380,746:,] = 0
        img[538:,679:] = 0
        img[555:,:]=0
    
    #imga = plt.imshow(img, interpolation='nearest',aspect='auto',cmap='gray')
    #plt.axis('off')
    #plt.tight_layout()
    #plt.savefig('/data/Gurpreet/VC/imgtemp.jpg', bbox_inches='tight')
    #io.imsave(save_file,img)
    
    misc.imsave(save_file,img)
    
    return img

# %%
Testfiles=pd.read_excel('/data/Gurpreet/Echo/View_point2.xlsx', sheetname='Test', header=0)
Trainfiles=pd.read_excel('/data/Gurpreet/Echo/View_point2.xlsx', sheetname='Train', header=0)

# %%
for i in xrange(0,((Testfiles.size/4))):
    patnumber=Testfiles.iloc[i,0]
    Videonumber=Testfiles.iloc[i,1]
    Viewplane=Testfiles.iloc[i,3]
    imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(Videonumber)+").dcm"
    print imgname+"    "+Viewplane
    [IMG,MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info2(imgname,nargout=4)
    IMG=np.asarray(IMG)    
    SoI=IMG.shape
    Totalframes=SoI[3]
    for j in xrange(1,Totalframes):
        IMG2=IMG[:,:,:,j]
        savename="/data/Gurpreet/Echo/RMOCR/TEST/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(j)+".jpg"
        #print savename
        IM=get_echo(IMG2,MANUFACTURER,WIDTH,HEIGHT,savename)
# Out:
# /data/Gurpreet/Echo/2/2(1).dcm    PLA
# /data/Gurpreet/Echo/2/2(2).dcm    PLA
# /data/Gurpreet/Echo/2/2(3).dcm    PLA
# /data/Gurpreet/Echo/2/2(13).dcm    PLA
# /data/Gurpreet/Echo/2/2(15).dcm    PLA
# /data/Gurpreet/Echo/2/2(20).dcm    SCX
# /data/Gurpreet/Echo/2/2(26).dcm    PSA
# /data/Gurpreet/Echo/2/2(27).dcm    PSA
# /data/Gurpreet/Echo/2/2(28).dcm    PSA
# /data/Gurpreet/Echo/2/2(29).dcm    PSA
# /data/Gurpreet/Echo/2/2(31).dcm    PSA
# /data/Gurpreet/Echo/2/2(33).dcm    PSA
# /data/Gurpreet/Echo/2/2(34).dcm    PSA
# /data/Gurpreet/Echo/2/2(35).dcm    PSA
# /data/Gurpreet/Echo/2/2(36).dcm    PSA
# /data/Gurpreet/Echo/2/2(37).dcm    PSA
# /data/Gurpreet/Echo/2/2(38).dcm    PSA
# /data/Gurpreet/Echo/2/2(39).dcm    PSA
# /data/Gurpreet/Echo/2/2(40).dcm    PSA
# /data/Gurpreet/Echo/2/2(41).dcm    PSA
# /data/Gurpreet/Echo/2/2(43).dcm    PLA
# /data/Gurpreet/Echo/2/2(47).dcm    A4C
# /data/Gurpreet/Echo/2/2(48).dcm    A4C
# /data/Gurpreet/Echo/2/2(69).dcm    A2C
# /data/Gurpreet/Echo/2/2(73).dcm    A4C
# /data/Gurpreet/Echo/2/2(78).dcm    A2C
# /data/Gurpreet/Echo/2/2(79).dcm    A4C
# /data/Gurpreet/Echo/2/2(82).dcm    SCX
# /data/Gurpreet/Echo/3/3(1).dcm    PLA
# /data/Gurpreet/Echo/3/3(2).dcm    PSA
# /data/Gurpreet/Echo/3/3(3).dcm    PLA
# /data/Gurpreet/Echo/3/3(7).dcm    A4C
# /data/Gurpreet/Echo/3/3(10).dcm    PLA
# /data/Gurpreet/Echo/3/3(13).dcm    PLA
# /data/Gurpreet/Echo/3/3(15).dcm    A2C
# /data/Gurpreet/Echo/3/3(18).dcm    PSA
# /data/Gurpreet/Echo/3/3(22).dcm    PSA
# /data/Gurpreet/Echo/3/3(25).dcm    PSA
# /data/Gurpreet/Echo/3/3(26).dcm    PSA
# /data/Gurpreet/Echo/3/3(28).dcm    PSA
# /data/Gurpreet/Echo/3/3(29).dcm    PSA
# /data/Gurpreet/Echo/3/3(30).dcm    PSA
# /data/Gurpreet/Echo/3/3(31).dcm    PSA
# /data/Gurpreet/Echo/3/3(32).dcm    PSA
# /data/Gurpreet/Echo/3/3(33).dcm    PSA
# /data/Gurpreet/Echo/3/3(34).dcm    PSA
# /data/Gurpreet/Echo/3/3(36).dcm    PSA
# /data/Gurpreet/Echo/3/3(38).dcm    PSA
# /data/Gurpreet/Echo/3/3(40).dcm    A4C
# /data/Gurpreet/Echo/3/3(42).dcm    A4C
# /data/Gurpreet/Echo/3/3(46).dcm    A4C
# /data/Gurpreet/Echo/3/3(47).dcm    PSA
# /data/Gurpreet/Echo/3/3(50).dcm    A2C
# /data/Gurpreet/Echo/3/3(63).dcm    A2C
# /data/Gurpreet/Echo/3/3(65).dcm    A2C
# /data/Gurpreet/Echo/3/3(67).dcm    A2C
# /data/Gurpreet/Echo/3/3(69).dcm    A4C
# /data/Gurpreet/Echo/3/3(70).dcm    SCX
# /data/Gurpreet/Echo/3/3(72).dcm    SCX
# /data/Gurpreet/Echo/4/4(1).dcm    PSA
# /data/Gurpreet/Echo/4/4(2).dcm    PLA
# /data/Gurpreet/Echo/4/4(6).dcm    PLA
# /data/Gurpreet/Echo/4/4(9).dcm    A2C
# /data/Gurpreet/Echo/4/4(12).dcm    A4C
# /data/Gurpreet/Echo/4/4(19).dcm    PSA
# /data/Gurpreet/Echo/4/4(26).dcm    PSA
# /data/Gurpreet/Echo/4/4(27).dcm    PSA
# /data/Gurpreet/Echo/4/4(29).dcm    PSA
# /data/Gurpreet/Echo/4/4(31).dcm    PSA
# /data/Gurpreet/Echo/4/4(34).dcm    PSA
# /data/Gurpreet/Echo/4/4(35).dcm    PSA
# /data/Gurpreet/Echo/4/4(36).dcm    PSA
# /data/Gurpreet/Echo/4/4(37).dcm    PSA
# /data/Gurpreet/Echo/4/4(38).dcm    PSA
# /data/Gurpreet/Echo/4/4(39).dcm    PSA
# /data/Gurpreet/Echo/4/4(40).dcm    PSA
# /data/Gurpreet/Echo/4/4(41).dcm    PSA
# /data/Gurpreet/Echo/4/4(42).dcm    PSA
# /data/Gurpreet/Echo/4/4(45).dcm    A4C
# /data/Gurpreet/Echo/4/4(52).dcm    A4C
# /data/Gurpreet/Echo/4/4(53).dcm    A4C
# /data/Gurpreet/Echo/4/4(57).dcm    A4C
# /data/Gurpreet/Echo/4/4(58).dcm    A3C
# /data/Gurpreet/Echo/4/4(60).dcm    A2C
# /data/Gurpreet/Echo/4/4(61).dcm    A2C
# /data/Gurpreet/Echo/4/4(62).dcm    A2C
# /data/Gurpreet/Echo/4/4(63).dcm    A4C
# /data/Gurpreet/Echo/4/4(65).dcm    A4C
# /data/Gurpreet/Echo/4/4(66).dcm    A4C
# /data/Gurpreet/Echo/4/4(67).dcm    A4C
# /data/Gurpreet/Echo/4/4(73).dcm    SCX
# /data/Gurpreet/Echo/4/4(74).dcm    SCX
# /data/Gurpreet/Echo/4/4(75).dcm    SCX
# /data/Gurpreet/Echo/4/4(83).dcm    SCX
# /data/Gurpreet/Echo/5/5(2).dcm    PLA
# /data/Gurpreet/Echo/5/5(13).dcm    A4C
# /data/Gurpreet/Echo/5/5(16).dcm    PLA
# /data/Gurpreet/Echo/5/5(18).dcm    PSA
# /data/Gurpreet/Echo/5/5(25).dcm    PSA
# /data/Gurpreet/Echo/5/5(30).dcm    PSA
# /data/Gurpreet/Echo/5/5(31).dcm    PSA
# /data/Gurpreet/Echo/5/5(32).dcm    PSA

# %%
for i in xrange(0,((Trainfiles.size/4))):
    patnumber=Testfiles.iloc[i,0]
    Videonumber=Testfiles.iloc[i,1]
    Viewplane=Testfiles.iloc[i,3]
    imgname="/data/Gurpreet/Echo/"+str(patnumber)+"/"+str(patnumber)+"("+str(patnumber)+").dcm"
    [IMG,MANUFACTURER,WIDTH,HEIGHT]=eng.get_file_and_info2(imgname,nargout=4)
    IMG=np.asarray(IMG)
    SoI=IMG.shape
    Totalframes=SoI[3]
    print imgname+"    "+Viewplane
    for j in xrange(1,Totalframes):
        IMG2=IMG[:,:,:,j]
        savename="/data/Gurpreet/Echo/RMOCR/TRAIN/"+str(Viewplane)+"/"+str(patnumber)+"_"+str(Videonumber)+"_"+str(j)+".jpg"
        IM=get_echo(IMG2,MANUFACTURER,WIDTH,HEIGHT,savename)
