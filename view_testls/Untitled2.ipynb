# %%
import sys
sys.path.append('/data/Gurpreet/CODE/VC2/view_testls/')
from Train_Resnet_Sets import Train_Resnet_Sets


mainfolder="/data/Gurpreet/RUNS/VC_12/"
number_of_sets=10
number_of_views=5
lr_decay=10
batch_size=100
epochs=20
Identifier="03072017_1032"
lr=0.001
Train_Resnet_Sets(mainfolder,number_of_sets,number_of_views,lr,lr_decay,batch_size,epochs,Identifier)
# Out:
# ...
# ==============================SET1==========================================================
# here
# {'test': 5249, 'train': 18269, 'val': 2661}
# ('Epoch = ', 0)
# ('lr = ', 0.001)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-15ec4865dfa7> in <module>()
#      12 Identifier="03072017_1032"
#      13 lr=0.001
# ---> 14 Train_Resnet_Sets(mainfolder,number_of_sets,number_of_views,lr,lr_decay,batch_size,epochs,Identifier)
#
# /data/Gurpreet/CODE/VC2/view_testls/Train_Resnet_Sets.pyc in Train_Resnet_Sets(mainfolder, number_of_sets, number_of_views, lr, lr_decay, batch_size, epochs, Identifier)
#      36         res.fc = nn.Linear(res.fc.in_features,number_of_views)
#      37         obj = model_pip(model_in=res,scale=True,batch_size=batch_size,use_gpu=True,gpu=2,data_path=datapath,lr=lr,lr_decay_epoch=lr_decay)
# ...
